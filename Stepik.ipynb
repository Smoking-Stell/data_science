# %% [markdown]
# <a href="https://colab.research.google.com/github/Smoking-Stell/data_science/blob/main/Stepik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
way = "/content/drive/MyDrive/Colab Notebooks/Stepik/"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Первые уроки

# %%
students_data = pd.read_csv(way + "StudentsPerformance.csv")
students_data.iloc[0:7]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
students_data.shape
# Out:
# (1000, 8)

# %%
df = pd.read_csv(way + "titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
students_data[(students_data['writing score'] > 80) & (students_data.gender == 'female')]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 36   female        group D          associate's degree      standard
# 38   female        group D          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 989  female        group D                some college  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
count = students_data.shape[0]
perc = students_data[students_data.lunch == "free/reduced"].shape[0]
ans_perc = perc/count
ans_perc
# Out:
# 0.355

# %%
std_lunch = students_data[students_data.lunch == "standard"]
free_lunch = students_data[students_data.lunch == "free/reduced"]
print(std_lunch["math score"].var() > free_lunch["math score"].var())
print(std_lunch["writing score"].var() > free_lunch["writing score"].var())
print(std_lunch["reading score"].var() > free_lunch["reading score"].var())
# Out:
# False
# False
# False

# %%
dota_stats = pd.read_csv(way + "dota_hero_stats.csv")

# %%
dota_stats
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
group_legs = dota_stats.groupby(["legs"]).count()

# %%
group_legs
# Out:
#       Unnamed: 0  attack_type  id  localized_name  name  primary_attr  roles
# legs
# 0             11           11  11              11    11            11     11
# 2             95           95  95              95    95            95     95
# 4              7            7   7               7     7             7      7
# 6              3            3   3               3     3             3      3
# 8              1            1   1               1     1             1      1

# %%
pupa_lupa = pd.read_csv(way + "accountancy.csv")
pupa_lupa
# Out:
#     Unnamed: 0 Executor Type  Salary
# 0            0     Pupa    D      63
# 1            1     Pupa    A     158
# 2            2     Pupa    D     194
# 3            3     Pupa    E     109
# 4            4    Loopa    E     184
# 5            5    Loopa    F     232
# 6            6    Loopa    B     249
# 7            7     Pupa    F     195
# 8            8     Pupa    A     115
# 9            9     Pupa    E      65
# 10          10    Loopa    C     145
# 11          11    Loopa    D     149
# 12          12    Loopa    B      50
# 13          13     Pupa    A     217
# 14          14    Loopa    D     110
# 15          15     Pupa    F      62
# 16          16     Pupa    A      55
# 17          17    Loopa    B     190
# 18          18    Loopa    E      83
# 19          19     Pupa    A     234
# 20          20    Loopa    E     156
# 21          21    Loopa    E     219
# 22          22     Pupa    C      55
# 23          23     Pupa    D     144
# ...

# %%
groups = pupa_lupa.groupby(["Executor", "Type"]).aggregate({"Salary" : "mean"})

# %%
groups
# Out:
#                    Salary
# Executor Type
# Loopa    A      58.000000
#          B     145.166667
#          C     154.333333
#          D     137.714286
#          E     164.000000
#          F     238.000000
# Pupa     A     160.833333
#          B      77.000000
#          C      74.500000
#          D     146.500000
#          E     131.200000
#          F     136.250000

# %%
at_atr = dota_stats.groupby(["attack_type", "primary_attr"]).describe()
at_atr
# Out:
#                          Unnamed: 0                                           \
#                               count       mean        std   min    25%   50%
# attack_type primary_attr
# Melee       agi                19.0  61.315789  38.233279   0.0  34.50  65.0
#             int                 2.0  67.500000  20.506097  53.0  60.25  67.5
#             str                35.0  62.657143  34.265351   1.0  31.50  69.0
# Ranged      agi                18.0  46.111111  32.737618   5.0  15.25  44.5
#             int                40.0  55.225000  32.472069   2.0  28.75  50.5
#             str                 3.0  84.666667  25.774665  57.0  73.00  89.0
#
#                                           id             ...                 \
#                             75%    max count       mean  ...     75%    max
# attack_type primary_attr                                 ...
# Melee       agi           89.00  114.0  19.0  63.315789  ...   91.00  120.0
# ...

# %%
algae = pd.read_csv(way + "algae.csv")
algae
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
mean_concentration = algae.groupby("genus")[algae.select_dtypes(include=[np.float64]).columns].aggregate("mean")

# %%
mean_concentration
# Out:
#               sucrose    alanin   citrate   glucose  oleic_acid
# genus
# Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# Cladophora   4.008792  3.997055  5.288311  2.800276    2.263472
# Fucus        4.355112  3.566411  4.214878  2.814803    3.367647
# Palmaria     0.704580  3.176440  5.573905  3.242090    2.245538
# Saccharina   4.183596  3.524207  3.346710  4.980594    4.487252

# %%
algae.select_dtypes(include=[np.float64]).columns
# Out:
# Index(['sucrose', 'alanin', 'citrate', 'glucose', 'oleic_acid'], dtype='object')

# %%
np.round(algae.query('genus == "Fucus"').alanin.describe(), decimals = 2)
# Out:
# count    3.00
# mean     3.57
# std      3.15
# min      0.35
# 25%      2.03
# 50%      3.71
# 75%      5.18
# max      6.64
# Name: alanin, dtype: float64

# %%
algae.groupby("group")[algae.select_dtypes(include=[np.float64]).columns].aggregate(["count", "var", "max", "min"])
# Out:
#       sucrose                               alanin                      \
#         count       var       max       min  count       var       max
# group
# brown       6  5.459098  6.825467  1.636122      6  7.220351  6.641303
# green       3  2.672626  5.712284  2.452623      3  7.059917  6.881024
# red         1       NaN  0.704580  0.704580      1       NaN  3.176440
#
#                 citrate                               glucose            \
#             min   count       var       max       min   count       var
# group
# brown  0.346431       6  5.468942  6.423606  1.071920       6  1.767756
# green  1.648450       3  3.950113  6.940588  3.082826       3  0.266265
# red    3.176440       1       NaN  5.573905  5.573905       1       NaN
#
#                           oleic_acid
#             max       min      count       var       max       min
# group
# brown  6.013219  2.272724          6  4.385233  6.405165  0.304573
# ...

# %% [markdown]
# # Рисование

# %%
students_data = pd.read_csv(way + "StudentsPerformance.csv")

# %%
students_data = students_data.rename(columns={"math score": "math_score", "reading score" : "reading_score", "writing score" : "writing_score"})
students_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math_score  reading_score  writing_score
# ...

# %%
students_data.math_score.hist()

# %%
sns.lmplot(x = 'math_score', y = 'writing_score', data = students_data)

# %%
income_data = pd.read_csv(way + "income.csv")
income_data
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
sns.lineplot(data=income_data)

# %%
df = pd.read_csv(way + "dataset_209770_6.txt", sep=" ")
df
# Out:
#               x            y
# 0    119.198149   898.674592
# 1   1093.234000   597.791828
# 2   1083.033781   589.094914
# 3   1300.696217  1198.180549
# 4   1105.369986   612.184320
# 5   1293.637241  1214.382785
# 6     85.626780   896.061187
# 7   1303.006629  1210.215279
# 8     90.770554   903.108507
# 9     99.608010   912.235144
# 10  1298.991123  1196.688356
# 11  1115.097619   599.241827
# 12   108.058087   892.927046
# 13  1097.700835   594.358656
# 14  1093.707016   597.807511
# 15  1299.901457  1210.570874
# 16  1098.236135   606.545689
# 17  1293.083529  1201.954792
# 18  1310.467939  1201.406131
# 19  1305.520294  1184.805073
# 20    99.759230   898.945003
# 21   101.382546   892.409346
# 22    97.972882   896.943060
# 23  1103.904792   619.710083
# 24    99.043249   892.563714
# 25    87.373788   903.660778
# 26  1094.645658   596.271449
# 27  1300.773984  1200.688281
# 28  1092.946486   607.918845
# 29  1290.621709  1204.111990

# %%
sns.lmplot(x = 'x', y = 'y', data = df)
sns.scatterplot(df.iloc[:, 0], df.iloc[:, 1])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
genom_data = pd.read_csv(way + "genome_matrix.csv", index_col = 0)
genom_data
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
colormap = sns.color_palette()
heatmap = sns.heatmap(genom_data, cmap="viridis")
heatmap.xaxis.set_ticks_position('top')
heatmap.xaxis.set_tick_params(rotation=90)

# %%
dota_stats = pd.read_csv(way + "dota_hero_stats.csv")
dota_stats["count_roles"] = dota_stats.apply(lambda x : len(x.roles.split(',')), axis = 1)
sns.histplot(data = dota_stats, x = "count_roles")

# %%
iris_stats = pd.read_csv(way + "iris.csv", index_col = 0)
for column in iris_stats:
    sns.kdeplot(iris_stats[str(column)])
plt.legend() 
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
sns.violinplot(data = iris_stats, y = "petal length")

# %%
sns.pairplot(data = iris_stats, hue = "species", palette = "viridis")

# %%
iris_stats.corr()
# Out:
#               sepal length  sepal width  petal length  petal width   species
# sepal length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000

# %% [markdown]
# # Третья часть

# %%
data_t = {'type' : ['A', 'A', 'B', 'B'], 'value' : [10, 14, 12, 23]}
my_data = pd.DataFrame(data = data_t, columns = ['type', 'value'])
my_data
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23

# %%
students_data = pd.read_csv(way + "StudentsPerformance.csv")
subset_1 = students_data.iloc[0:10, [1,3]]
subset_1
subset_2 = students_data.iloc[:, [2, 4]].drop([0, 4])
subset_2
# Out:
#     parental level of education test preparation course
# 1                  some college               completed
# 2               master's degree                    none
# 3            associate's degree                    none
# 5            associate's degree                    none
# 6                  some college               completed
# ..                          ...                     ...
# 995             master's degree               completed
# 996                 high school                    none
# 997                 high school               completed
# 998                some college               completed
# 999                some college                    none
#
# [998 rows x 2 columns]
