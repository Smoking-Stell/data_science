# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
way = "/content/drive/MyDrive/Colab_Notebooks/data_science/datasets/"
# Out:
# Mounted at /content/drive

# %%
df_train = pd.read_csv(way + 'train_filmreviews.csv')
df_test = pd.read_csv(way + 'test_filmreviews.csv')

# %%
df_train = df_train.rename({'0' : 'grade'}, axis = 1)
df_test = df_test.rename({'0' : 'grade'}, axis = 1)

# %%
df_train.sample(5)
# Out:
#        label                                               text  grade
# 24020      0  ['actually', 'saw', 'movie', 'theater', 'back'...      1
# 12536      0  ['storyline', 'okay', 'akshay', 'kumar', 'good...      4
# 895        1  ['felt', 'film', 'throughout', 'waas', 'impres...      9
# 2131       1  ['movie', 'perfect', 'family', 'watch', 'toget...      7
# 5549       1  ['many', 'mystery', 'story', 'follow', 'standa...     10

# %%
df_test.sample(5)
# Out:
#        label                                               text  grade
# 12464      1  ['welsh', 'poet', 'dylan', 'thomas', 'excuse',...      7
# 13627      0  ['another', 'film', 'remember', 'kid', 'recent...      4
# 17464      0  ['deal', 'ethnic', 'crime', 'group', 'copying'...      1
# 4470       1  ['nnot', 'ever', 'miss', 'good', 'old', 'day',...     10
# 15235      0  ['rule', 'try', 'find', 'much', 'film', 'possi...      1

# %%
x_train = df_train['text']
y_train = df_train['grade']
x_test = df_test['text']
y_test = df_test['grade']
